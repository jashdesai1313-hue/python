# %%
class Vehicle:
  def __init__(self, name, max_speed, mileage):
    self.name = name
    self.max_speed = max_speed
    self.mileage = mileage
class Bus(Vehicle):
    pass
School_Bus=Bus("School Volvo", 180, 12)
print("Vehicle name:", School_Bus.name, "Speed:", School_Bus.max_speed, "Mileage:", School_Bus.mileage)
# Out:
# Vehicle name: School Volvo Speed: 180 Mileage: 12

# %%
class Person( object ):
  def __init__(self, name, idnumber):
    self.name = name
    self.idnumber = idnumber
  def display(self):
    print(self.name)
    print(self.idnumber)
class Employee( Person ):
  def __init__(self, name, idnumber, salary, post):
    self.salary = salary
    self.post = post
    Person.__init__(self, name, idnumber)
a = Employee('rahul', 886012, 200000, "intern")
a.display()
# Out:
# rahul
# 886012

# %%
class Bird:
  def __init__(self):
    print("Bird")
  def whoisThis(self):
    print("Bird")
  def swim(self):
    print("Swim faster")
class Penguin(Bird):
  def __init__(self):
    super().__init__()
    print("penguin is ready")
  def whoisThis(self):
    print("Penguin")
  def run(self):
    print("run faster")
peggy=Penguin
peggy.whoisThis()
peggy.swim()
peggy.run
# Out:
# Penguin
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2342/1945980281.py in <cell line: 0>()
#      16 peggy=Penguin
#      17 peggy.whoisThis('self')
# ---> 18 peggy.swim()
#      19 peggy.run
#
# TypeError: Bird.swim() missing 1 required positional argument: 'self'
