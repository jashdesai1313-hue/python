# %% [markdown]
# <a href="https://colab.research.google.com/github/jashdesai1313-hue/python/blob/main/Copy_of_Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("half pyramid pattern of stars(*):")
n = int(input("enter the number of rows:"))
for i in range(1, n+1):
    print(" "*(n-i), end=" ")
    print("*"*i)
# Out:
# half pyramid pattern of stars(*):
# enter the number of rows:4
#     *
#    **
#   ***
#  ****
