# %% [markdown]
# <a href="https://colab.research.google.com/github/jashdesai1313-hue/python/blob/main/dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
student_data={"id1":
              {"name":["sara"], "class": ["5th"], "subject_intergration": ["english, math, science"]},
              "id2":
              {"name":["jack"], "class": ["5th"], "subject_intergration": ["english, math, science"]},
              "id3":
              {"name":["david"], "class": ["5th"], "subject_intergration": ["english, math, science"]},
              "id4":
              {"name":["bob"], "class": ["5th"], "subject_intergration": ["english, math, science"]},}
result={}
for key,value in student_data.items():
    if value not in result.values():
        result[key]=value
print(result)
# Out:
# {'id1': {'name': ['sara'], 'class': ['5th'], 'subject_intergration': ['english, math, science']}, 'id2': {'name': ['jack'], 'class': ['5th'], 'subject_intergration': ['english, math, science']}, 'id3': {'name': ['david'], 'class': ['5th'], 'subject_intergration': ['english, math, science']}, 'id4': {'name': ['bob'], 'class': ['5th'], 'subject_intergration': ['english, math, science']}}

# %%
test_dic = {'Codingal':2, 'is':2, 'best':2, 'for':2, 'Coding':1}
print("the original dictionary is:", test_dic)
k=2
result=0
for key in test_dic:
   if test_dic[key]==k:
    result+=1
print("frequency of k is", result)
# Out:
# the original dictionary is: {'Codingal': 2, 'is': 2, 'best': 2, 'for': 2, 'Coding': 1}
# frequency of k is 4

# %%
country_code={"india": "0091", "australia": "0025", "nepal": "00977"}
print("country code for india is", country_code.get("india", "not found"))
print("country code for canada is", country_code.get("canada", "not found"))
# Out:
# country code for india is 0091
# country code for canada is not found
