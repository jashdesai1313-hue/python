# %% [markdown]
# <a href="https://colab.research.google.com/github/jashdesai1313-hue/python/blob/main/list_datatype.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_list1=[]
print()

numbers=[1, 2, 3, 4, 5]
print(numbers)

x=[1, 2, 3]*3
print(x)

y=[10, 20, 30, 40, 50]
y=y[::-1]
print(y, "\n")
# Out:
# [1, 2, 3, 4, 5]
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# [50, 40, 30, 20, 10]

# %%
def check(words):
  c=0
  lst=[]
  for i in words:
    if len(i)>1 and i[0]==i[-1]:
      c+=1
      lst.append(i)
  print("list of words with first and last character same \n", lst)
  return c
count=check(["abc","cfc","xyz","aba","1221"])
print("number of words having first and last character same:", count)
# Out:
# list of words with first and last character same
#  ['cfc', 'aba', '1221']
# number of words having first and last character same: 3

# %%
lst=[1,4,6,2,5,8,0,12,7,3,2,5]
print("original list is", lst)
count=0
for i in lst:
  count+=i
avg=count/len(lst)
print("sum is:", count)
print( "and average is", avg)
lst.sort()
print("smallest element is", lst[0])
print("largest element is", lst[-1])
# Out:
# original list is [1, 4, 6, 2, 5, 8, 0, 12, 7, 3, 2, 5]
# sum is: 55
# and average is 4.583333333333333
# smallest element is 0
# largest element is 12
