# %% [markdown]
# <a href="https://colab.research.google.com/github/jashdesai1313-hue/python/blob/main/random_and_math_module.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
playing=True
number=str(random.randint(1,3))
print("i will generate a number between 1 and 10 and you have to guess the number 1 digit at a time")
while playing:
  guess=input("give me your best guess \n")3
  if number==guess:
    print("you won 50,000,000 rupees")
    print("the number was", number)
    break
  else:
    print("your guess isnt quite right, try again \n")
# Out:
# i will generate a number between 1 and 10 and you have to guess the number 1 digit at a time
# give me your best guess
# 1
# your guess isnt quite right, try again
#
# give me your best guess
# 1
# your guess isnt quite right, try again
#
# give me your best guess
# 2
# you won 50,000,000 rupees
# the number was 2
