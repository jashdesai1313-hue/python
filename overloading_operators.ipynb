# %% [markdown]
# <a href="https://colab.research.google.com/github/jashdesai1313-hue/python/blob/main/overloading_operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class A:
  def __init__(self, a):
    self.a = a
  def __lt__(self, other):
    if(self.a < other.a):
      return "ob1 is less than ob2"
    else:
      return "ob2 is less than ob1"
  def __eq__(self, other):
    if self.a == other.a:
      return "both are equal"
    else:
      return "not equal"
ob1 = A(2)
ob2 = A(3)
print("passed values", ob1.a, ob2.a)
print(ob1 < ob2)
ob3 = A(4)
ob4 = A(4)
print("passed values", ob3.a, ob4.a)
print(ob3 == ob4)
# Out:
# passed values 2 3
# ob1 is less than ob2
# passed values 4 4
# both are equal

# %%
class flashcard:
  def __init__(self, word, meaning):
    self.word = word
    self.meaning = meaning
  def __str__(self):
    return self.word+ '( '+self.meaning+' )'
flash = []
print("welcome to the flashcard application")
while(True):
  word = input("enter the name you want to add to the flashcard:")
  meaning = input("enter the meaning of the word:")
  flash.append(flashcard(word, meaning))
  option = int(input("enter 0, if you want to add another flashcard, otherwise enter 1:"))
  if(option):
    break
print("\nYour flashcards")
for i in flash:
  print(">", i)
# Out:
# welcome to the flashcard application
# enter the name you want to add to the flashcard:hi
# enter the meaning of the word:a name
# enter 0, if you want to add another flashcard, otherwise enter 1:0
# enter the name you want to add to the flashcard:hi
# enter the meaning of the word:a greeting
# enter 0, if you want to add another flashcard, otherwise enter 1:0
# enter the name you want to add to the flashcard:hi
# enter the meaning of the word:name
# enter 0, if you want to add another flashcard, otherwise enter 1:0
# enter the name you want to add to the flashcard:hi
# enter the meaning of the word:name
# enter 0, if you want to add another flashcard, otherwise enter 1:1
#
# Your flashcards
# > hi( a name )
# > hi( a greeting )
# > hi( name )
# > hi( name )

# %%
import random
class FruitQuiz:
  def __init__(self):
    self.fruits = {'apple':'red',
                   'orange':'orange',
                   'watermelon':'green',
                   'bananna':'yellow'}
  def quiz(self):
    while (True):
      fruit, color = random.choice(list(self.fruit.items()))
      print("what is the colour of {}".format(fruit))
      user_answer = input()
      if (user_answer.lower() == color):
        print("correct answer")
      else:
        print("wrong answer")
print("welcome to fruit quiz")
fq=FruitQuiz()
fq.quiz()
# Out:
# welcome to fruit quiz
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_152/2759142172.py in <cell line: 0>()
#      17 print("welcome to fruit quiz")
#      18 fq=FruitQuiz()
# ---> 19 fq.quiz()
#
# /tmp/ipykernel_152/2759142172.py in quiz(self)
#       8   def quiz(self):
#       9     while (True):
# ---> 10       fruit, color = random.choice(list(self.fruit.items()))
#      11       print("what is the colour of {}".format(fruit))
#      12       user_answer = input()
#
# AttributeError: 'FruitQuiz' object has no attribute 'fruit'
