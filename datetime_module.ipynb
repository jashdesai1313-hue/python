# %% [markdown]
# <a href="https://colab.research.google.com/github/jashdesai1313-hue/python/blob/main/datetime_module.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import datetime, date, time
today=date.today()
now=datetime.now()
print("todays date is", today )
print("\n the current date and time is", now)
print("\n date components are", today.year, today.month, today.day)
print("\n time components are", now.hour, now.minute, now.second)
# Out:
# todays date is 2026-01-17
#
#  the current date and time is 2026-01-17 07:16:15.158168
#
#  date components are 2026 1 17
#
#  time components are 7 16 15
