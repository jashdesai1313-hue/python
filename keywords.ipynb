# %% [markdown]
# <a href="https://colab.research.google.com/github/jashdesai1313-hue/python/blob/main/keywords.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
b=input("enter any word:")
for i in b:
  if(i=='a' or i=='A'):
    print("a is found")
    break
  else:
    print("a is not found")
# Out:
# enter any word:JASH
# a is not found
# a is found
