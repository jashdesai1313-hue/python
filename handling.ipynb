# %% [markdown]
# <a href="https://colab.research.google.com/github/jashdesai1313-hue/python/blob/main/handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  number=int(input("enter a number:"))
  print("the number is:", number)
except ValueError as ex:
  print("exception:", ex)
# Out:
# enter a number:drh
# exception: invalid literal for int() with base 10: 'drh'
