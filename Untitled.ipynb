# %% [markdown]
# <a href="https://colab.research.google.com/github/jashdesai1313-hue/python/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class student:
  grade = 10
  print("hi, i am a student of grade", grade)
ob=student
# Out:
# hi, i am a student of grade 10

# %%
class Vehicle:
 def __init__(self,max_speed,mileage):
  self.max_speed=max_speed
  self.mileage=mileage
modelX=Vehicle(240,18)
print("max speed:", modelX.max_speed)
print("mileage:" ,modelX.mileage)
# Out:
# max speed: 240
# mileage: 18
